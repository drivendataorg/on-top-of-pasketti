# %%
import pandas as pd
from tqdm import tqdm
import json
import os

path = 'data/'
version ='X4090D-v013'
os.makedirs(path+'models',exist_ok=True)
os.makedirs(path+f'feature',exist_ok=True)
os.makedirs(path+f'feature_importance',exist_ok=True)
os.makedirs(path+'submissions',exist_ok=True)
os.makedirs(path+'logs',exist_ok=True)

fold='train'

# %%
train_df1 = pd.read_json('data/train_word_transcripts.jsonl',lines=True)
train_df1['audio_path'] = 'data/'+train_df1['audio_path']
train_df1
# Out:
#              utterance_id            child_id          session_id  \
# 0      U_00003c3ae1c35c6f  C_c74bfde2cca8d5da  S_7d821c3e4d3bc616
# 1      U_00003db24218ffe4  C_c74bfde2cca8d5da  S_e6103ab3a4538d71
# 2      U_0001a0d0a3b4d816  C_4d0e1c16566d65a2  S_179057c3c3ccdecf
# 3      U_00021d201a31d313  C_3b51c8b1d2c076d8  S_90720887e4430996
# 4      U_0003537f2bc1eb0b  C_b50216b3c70ca0a2  S_5b0bb48fadd7f802
# ...                   ...                 ...                 ...
# 95567  U_fffb5523ed9ea68f  C_c83f7ae3cffb9886  S_d655267f8a31b651
# 95568  U_fffd3181ab3dbb35  C_eb21c5635ec2a5fb  S_42e77ca587ff78c8
# 95569  U_fffd9ee77192956d  C_29528791cd81a931  S_75d13a9058485876
# 95570  U_fffe57f6f30a4915  C_6354527999b15da1  S_8b1d247b058f5073
# 95571  U_ffffb1ed7591f5d9  C_c18f8e42de7c42a7  S_1a4afe61b24eaf9d
#
#                                audio_path  audio_duration_sec age_bucket  \
# 0      data/audio/U_00003c3ae1c35c6f.flac               1.920       8-11
# 1      data/audio/U_00003db24218ffe4.flac              12.737       8-11
# 2      data/audio/U_0001a0d0a3b4d816.flac              11.556       8-11
# 3      data/audio/U_00021d201a31d313.flac               1.125       8-11
# 4      data/audio/U_0003537f2bc1eb0b.flac               1.125       8-11
# ...                                   ...                 ...        ...
# 95567  data/audio/U_fffb5523ed9ea68f.flac               0.336       8-11
# 95568  data/audio/U_fffd3181ab3dbb35.flac               6.217       8-11
# 95569  data/audio/U_fffd9ee77192956d.flac              22.759       8-11
# 95570  data/audio/U_fffe57f6f30a4915.flac               2.184        3-4
# 95571  data/audio/U_ffffb1ed7591f5d9.flac               1.072       8-11
#
#                                md5_hash  filesize_bytes  \
# 0      9214be45ba2928dd57384f3c7ee54236           30672
# 1      fe761bb3d034530ef05163c7ad98ec3e          180942
# 2      b05073e65a98368fccbe777b5ab35e02          208352
# 3      9ed95318724ae6a2d1ce95d6aa743f6b           27099
# 4      f3142751c6a52e2c24a85a4544fe8a0f           18476
# ...                                 ...             ...
# 95567  c7853e8f492c21f7f35b29ea997976dc           14658
# 95568  4fe7f0926491d13fc5599d0b3be8a5d2          110716
# 95569  617363baa65950b9adae023ccad29036          496115
# 95570  aaa0a3724331acdae526bc10c20361d7          178906
# 95571  b8dec52efd25a3b6ad6cb3b39985a51b           31691
#
#                                        orthographic_text
# 0                                                     hm
# 1      yeah its pouring the water on the screen but t...
# 2      it got water and sunlight but the plant did di...
# 3                                         there is wires
# 4                                                   good
# ...                                                  ...
# 95567                                          thank you
# 95568  the wax is going off and the fire's moving around
# 95569  well the reason they're dimmer is because um t...
# 95570                         i think this go right here
# 95571                                       i don't know
#
# [95572 rows x 9 columns]

# %%
train_df2 = pd.read_json('data/TalkBank_corpus/train_word_transcripts.jsonl',lines=True)
train_df2['audio_path'] = 'data/TalkBank_corpus/'+train_df2['audio_path']
train_df2
# Out:
#               utterance_id            child_id          session_id  \
# 0       U_00007df27e1aad33  C_051ec7d3c1c79ea0  S_9fa42bab5070de99
# 1       U_0000891c5dd8a029  C_bb6d9ae9daeb252f  S_c0372465b6a6d449
# 2       U_000115d21a4e9803  C_8cb9e2715147169e  S_e040bd862833a42e
# 3       U_00016e37f6f492d0  C_8bec179ceec547ea  S_16268a4120aaaf41
# 4       U_00018bc22b7f1b7d  C_81d265d4c30a75c0  S_007b697d81ac2ec4
# ...                    ...                 ...                 ...
# 255041  U_ffff47e74b3df4bd  C_eeef9cde2a489d3e  S_a4374ef38a06c9d3
# 255042  U_ffff5a85835f4381  C_c8dacd6170ef3dac  S_0513c82716cf293e
# 255043  U_ffff9511f5573d86  C_19d203c2d174b50a  S_12ad2436005232a1
# 255044  U_ffffcc5a06582c0f  C_528d220b627fbbf5  S_d96ff7b629fc2b49
# 255045  U_fffffed52bdd542e  C_fac67e904dbdf6c3  S_ae7e70ffc0f2ea10
#
#                                                audio_path  audio_duration_sec  \
# 0       /home/ubuntu/Desktop/audio/audio/U_00007df27e1...               0.656
# 1       /home/ubuntu/Desktop/audio/audio/U_0000891c5dd...               0.615
# 2       /home/ubuntu/Desktop/audio/audio/U_000115d21a4...               1.095
# 3       /home/ubuntu/Desktop/audio/audio/U_00016e37f6f...               1.457
# 4       /home/ubuntu/Desktop/audio/audio/U_00018bc22b7...               0.938
# ...                                                   ...                 ...
# 255041  /home/ubuntu/Desktop/audio/audio/U_ffff47e74b3...               4.651
# 255042  /home/ubuntu/Desktop/audio/audio/U_ffff5a85835...               0.750
# 255043  /home/ubuntu/Desktop/audio/audio/U_ffff9511f55...               6.264
# 255044  /home/ubuntu/Desktop/audio/audio/U_ffffcc5a065...               0.951
# 255045  /home/ubuntu/Desktop/audio/audio/U_fffffed52bd...               1.825
#
#        age_bucket                          md5_hash  filesize_bytes  \
# 0             12+  3c06f408d812a597f0bc40551e88587c           21843
# 1            8-11  bed60778ecb0512df8b9ed8b87a2dbc4           40091
# 2            8-11  026c0732f280756a145201e109614fab           53900
# 3            8-11  1b37fdc261a6238afa5360db72d5b0ed           83925
# 4             3-4  0a844e8696b379c5f6700a9a1cd06360           38385
# ...           ...                               ...             ...
# 255041        3-4  993dadaabfc3c6a47cbd6e774251ca4c          199287
# 255042       8-11  63cbc529895536ede8643efd23ddd81f           64774
# 255043        5-7  f2dd7b7a0395cad6c6cdc8085cdb702c          274322
# 255044        3-4  ac2d88c0c6ef9a27d9ef338ae0c450fa           42610
# 255045        5-7  62018d5ec1f20b9c270a3ff71959c2de           68091
#
#                                         orthographic_text
# 0                                                      er
# 1                                                    azoo
# 2                            and then there's like a shop
# 3                                                      um
# 4                                                   stars
# ...                                                   ...
# 255041                            sock hop on pop top fox
# 255042                                             was it
# 255043  and you get to have a little break in there be...
# 255044                                             orange
# 255045                                            two foo
#
# [255046 rows x 9 columns]

# %%
len(set(train_df1['child_id'])&set(train_df2['child_id']))
# Out:
# 0

# %%
train_df = pd.concat([train_df1,train_df2]).reset_index(drop=True)
train_df
# Out:
#               utterance_id            child_id          session_id  \
# 0       U_00003c3ae1c35c6f  C_c74bfde2cca8d5da  S_7d821c3e4d3bc616
# 1       U_00003db24218ffe4  C_c74bfde2cca8d5da  S_e6103ab3a4538d71
# 2       U_0001a0d0a3b4d816  C_4d0e1c16566d65a2  S_179057c3c3ccdecf
# 3       U_00021d201a31d313  C_3b51c8b1d2c076d8  S_90720887e4430996
# 4       U_0003537f2bc1eb0b  C_b50216b3c70ca0a2  S_5b0bb48fadd7f802
# ...                    ...                 ...                 ...
# 350613  U_ffff47e74b3df4bd  C_eeef9cde2a489d3e  S_a4374ef38a06c9d3
# 350614  U_ffff5a85835f4381  C_c8dacd6170ef3dac  S_0513c82716cf293e
# 350615  U_ffff9511f5573d86  C_19d203c2d174b50a  S_12ad2436005232a1
# 350616  U_ffffcc5a06582c0f  C_528d220b627fbbf5  S_d96ff7b629fc2b49
# 350617  U_fffffed52bdd542e  C_fac67e904dbdf6c3  S_ae7e70ffc0f2ea10
#
#                                                audio_path  audio_duration_sec  \
# 0                      data/audio/U_00003c3ae1c35c6f.flac               1.920
# 1                      data/audio/U_00003db24218ffe4.flac              12.737
# 2                      data/audio/U_0001a0d0a3b4d816.flac              11.556
# 3                      data/audio/U_00021d201a31d313.flac               1.125
# 4                      data/audio/U_0003537f2bc1eb0b.flac               1.125
# ...                                                   ...                 ...
# 350613  /home/ubuntu/Desktop/audio/audio/U_ffff47e74b3...               4.651
# 350614  /home/ubuntu/Desktop/audio/audio/U_ffff5a85835...               0.750
# 350615  /home/ubuntu/Desktop/audio/audio/U_ffff9511f55...               6.264
# 350616  /home/ubuntu/Desktop/audio/audio/U_ffffcc5a065...               0.951
# 350617  /home/ubuntu/Desktop/audio/audio/U_fffffed52bd...               1.825
#
#        age_bucket                          md5_hash  filesize_bytes  \
# 0            8-11  9214be45ba2928dd57384f3c7ee54236           30672
# 1            8-11  fe761bb3d034530ef05163c7ad98ec3e          180942
# 2            8-11  b05073e65a98368fccbe777b5ab35e02          208352
# 3            8-11  9ed95318724ae6a2d1ce95d6aa743f6b           27099
# 4            8-11  f3142751c6a52e2c24a85a4544fe8a0f           18476
# ...           ...                               ...             ...
# 350613        3-4  993dadaabfc3c6a47cbd6e774251ca4c          199287
# 350614       8-11  63cbc529895536ede8643efd23ddd81f           64774
# 350615        5-7  f2dd7b7a0395cad6c6cdc8085cdb702c          274322
# 350616        3-4  ac2d88c0c6ef9a27d9ef338ae0c450fa           42610
# 350617        5-7  62018d5ec1f20b9c270a3ff71959c2de           68091
#
#                                         orthographic_text
# 0                                                      hm
# 1       yeah its pouring the water on the screen but t...
# 2       it got water and sunlight but the plant did di...
# 3                                          there is wires
# 4                                                    good
# ...                                                   ...
# 350613                            sock hop on pop top fox
# 350614                                             was it
# 350615  and you get to have a little break in there be...
# 350616                                             orange
# 350617                                            two foo
#
# [350618 rows x 9 columns]

# %%
# from joblib import Parallel, delayed
# import librosa
# def check_audio_file(file_path):
#     """
#     尝试加载一个音频文件。
#     如果成功，返回 None。
#     如果失败，返回文件路径。
#     """
#     try:
#         # 我们只需要检查是否能加载，不需要完整数据，可以设置duration来加速
#         # 如果文件很大，这个优化会非常有用
#         wav, _ = librosa.load(file_path, sr=16000, mono=True)
#         return None
#     except Exception as e:
#         # 打印错误信息是可选的，但有助于调试
#         print(f"无法加载文件 {file_path}: {e}")
#         return file_path


# # 2. 使用Joblib进行并行处理
# # 获取所有文件路径列表
# audio_paths = train_df['audio_path'].tolist()

# print("开始并行检查音频文件...")
# results = Parallel(n_jobs=30, backend='multiprocessing')(
#     delayed(check_audio_file)(path) for path in tqdm(audio_paths)
# )
# results = [i for i in results if i is not None]
# len(results)

# %%
child_ids = sorted(set(train_df['child_id']))

# %%
train_child_ids = child_ids[:len(child_ids)//10*9]

# %%
import numpy as np
train_df = train_df[train_df['audio_duration_sec']<20]
train_df = train_df[train_df['utterance_id']!='U_b8a4e8220e65219b'].reset_index(drop=True)
train_df['split']=np.where(train_df['child_id'].isin(train_child_ids),'train','split')
train_df
# Out:
#               utterance_id            child_id          session_id  \
# 0       U_00003c3ae1c35c6f  C_c74bfde2cca8d5da  S_7d821c3e4d3bc616
# 1       U_00003db24218ffe4  C_c74bfde2cca8d5da  S_e6103ab3a4538d71
# 2       U_0001a0d0a3b4d816  C_4d0e1c16566d65a2  S_179057c3c3ccdecf
# 3       U_00021d201a31d313  C_3b51c8b1d2c076d8  S_90720887e4430996
# 4       U_0003537f2bc1eb0b  C_b50216b3c70ca0a2  S_5b0bb48fadd7f802
# ...                    ...                 ...                 ...
# 343790  U_ffff47e74b3df4bd  C_eeef9cde2a489d3e  S_a4374ef38a06c9d3
# 343791  U_ffff5a85835f4381  C_c8dacd6170ef3dac  S_0513c82716cf293e
# 343792  U_ffff9511f5573d86  C_19d203c2d174b50a  S_12ad2436005232a1
# 343793  U_ffffcc5a06582c0f  C_528d220b627fbbf5  S_d96ff7b629fc2b49
# 343794  U_fffffed52bdd542e  C_fac67e904dbdf6c3  S_ae7e70ffc0f2ea10
#
#                                                audio_path  audio_duration_sec  \
# 0                      data/audio/U_00003c3ae1c35c6f.flac               1.920
# 1                      data/audio/U_00003db24218ffe4.flac              12.737
# 2                      data/audio/U_0001a0d0a3b4d816.flac              11.556
# 3                      data/audio/U_00021d201a31d313.flac               1.125
# 4                      data/audio/U_0003537f2bc1eb0b.flac               1.125
# ...                                                   ...                 ...
# 343790  /home/ubuntu/Desktop/audio/audio/U_ffff47e74b3...               4.651
# 343791  /home/ubuntu/Desktop/audio/audio/U_ffff5a85835...               0.750
# 343792  /home/ubuntu/Desktop/audio/audio/U_ffff9511f55...               6.264
# 343793  /home/ubuntu/Desktop/audio/audio/U_ffffcc5a065...               0.951
# 343794  /home/ubuntu/Desktop/audio/audio/U_fffffed52bd...               1.825
#
#        age_bucket                          md5_hash  filesize_bytes  \
# 0            8-11  9214be45ba2928dd57384f3c7ee54236           30672
# 1            8-11  fe761bb3d034530ef05163c7ad98ec3e          180942
# 2            8-11  b05073e65a98368fccbe777b5ab35e02          208352
# 3            8-11  9ed95318724ae6a2d1ce95d6aa743f6b           27099
# 4            8-11  f3142751c6a52e2c24a85a4544fe8a0f           18476
# ...           ...                               ...             ...
# 343790        3-4  993dadaabfc3c6a47cbd6e774251ca4c          199287
# 343791       8-11  63cbc529895536ede8643efd23ddd81f           64774
# 343792        5-7  f2dd7b7a0395cad6c6cdc8085cdb702c          274322
# 343793        3-4  ac2d88c0c6ef9a27d9ef338ae0c450fa           42610
# 343794        5-7  62018d5ec1f20b9c270a3ff71959c2de           68091
#
#                                         orthographic_text  split
# 0                                                      hm  train
# 1       yeah its pouring the water on the screen but t...  train
# 2       it got water and sunlight but the plant did di...  train
# 3                                          there is wires  train
# 4                                                    good  train
# ...                                                   ...    ...
# 343790                            sock hop on pop top fox  split
# 343791                                             was it  train
# 343792  and you get to have a little break in there be...  train
# 343793                                             orange  train
# 343794                                            two foo  split
#
# [343795 rows x 10 columns]

# %%
valid_df=train_df[train_df['split']!=fold].reset_index(drop=True)
# train_df=train_df[train_df['split']==fold].reset_index(drop=True)

# %%
train_df.shape,valid_df.shape
# Out:
# ((343795, 10), (38300, 10))

# %%
train_df
# Out:
#               utterance_id            child_id          session_id  \
# 0       U_00003c3ae1c35c6f  C_c74bfde2cca8d5da  S_7d821c3e4d3bc616
# 1       U_00003db24218ffe4  C_c74bfde2cca8d5da  S_e6103ab3a4538d71
# 2       U_0001a0d0a3b4d816  C_4d0e1c16566d65a2  S_179057c3c3ccdecf
# 3       U_00021d201a31d313  C_3b51c8b1d2c076d8  S_90720887e4430996
# 4       U_0003537f2bc1eb0b  C_b50216b3c70ca0a2  S_5b0bb48fadd7f802
# ...                    ...                 ...                 ...
# 343790  U_ffff47e74b3df4bd  C_eeef9cde2a489d3e  S_a4374ef38a06c9d3
# 343791  U_ffff5a85835f4381  C_c8dacd6170ef3dac  S_0513c82716cf293e
# 343792  U_ffff9511f5573d86  C_19d203c2d174b50a  S_12ad2436005232a1
# 343793  U_ffffcc5a06582c0f  C_528d220b627fbbf5  S_d96ff7b629fc2b49
# 343794  U_fffffed52bdd542e  C_fac67e904dbdf6c3  S_ae7e70ffc0f2ea10
#
#                                                audio_path  audio_duration_sec  \
# 0                      data/audio/U_00003c3ae1c35c6f.flac               1.920
# 1                      data/audio/U_00003db24218ffe4.flac              12.737
# 2                      data/audio/U_0001a0d0a3b4d816.flac              11.556
# 3                      data/audio/U_00021d201a31d313.flac               1.125
# 4                      data/audio/U_0003537f2bc1eb0b.flac               1.125
# ...                                                   ...                 ...
# 343790  /home/ubuntu/Desktop/audio/audio/U_ffff47e74b3...               4.651
# 343791  /home/ubuntu/Desktop/audio/audio/U_ffff5a85835...               0.750
# 343792  /home/ubuntu/Desktop/audio/audio/U_ffff9511f55...               6.264
# 343793  /home/ubuntu/Desktop/audio/audio/U_ffffcc5a065...               0.951
# 343794  /home/ubuntu/Desktop/audio/audio/U_fffffed52bd...               1.825
#
#        age_bucket                          md5_hash  filesize_bytes  \
# 0            8-11  9214be45ba2928dd57384f3c7ee54236           30672
# 1            8-11  fe761bb3d034530ef05163c7ad98ec3e          180942
# 2            8-11  b05073e65a98368fccbe777b5ab35e02          208352
# 3            8-11  9ed95318724ae6a2d1ce95d6aa743f6b           27099
# 4            8-11  f3142751c6a52e2c24a85a4544fe8a0f           18476
# ...           ...                               ...             ...
# 343790        3-4  993dadaabfc3c6a47cbd6e774251ca4c          199287
# 343791       8-11  63cbc529895536ede8643efd23ddd81f           64774
# 343792        5-7  f2dd7b7a0395cad6c6cdc8085cdb702c          274322
# 343793        3-4  ac2d88c0c6ef9a27d9ef338ae0c450fa           42610
# 343794        5-7  62018d5ec1f20b9c270a3ff71959c2de           68091
#
#                                         orthographic_text  split
# 0                                                      hm  train
# 1       yeah its pouring the water on the screen but t...  train
# 2       it got water and sunlight but the plant did di...  train
# 3                                          there is wires  train
# 4                                                    good  train
# ...                                                   ...    ...
# 343790                            sock hop on pop top fox  split
# 343791                                             was it  train
# 343792  and you get to have a little break in there be...  train
# 343793                                             orange  train
# 343794                                            two foo  split
#
# [343795 rows x 10 columns]

# %%
with open(path+f'feature/train_{version}.jsonl', 'w',  encoding='utf-8') as fw:
    for idx,audio in enumerate(train_df['audio_path']):
        s = {"audio": audio, "text": "language English<asr_text>"+train_df['orthographic_text'][idx]}
        s = json.dumps(s, ensure_ascii=False)
        fw.write(s + '\n')

# %%
with open(path+f'feature/valid_{version}.jsonl', 'w',  encoding='utf-8') as fw:
    for idx,audio in enumerate(valid_df['audio_path']):
        s = {"audio": audio, "text": "language English<asr_text>"+valid_df['orthographic_text'][idx]}
        s = json.dumps(s, ensure_ascii=False)
        fw.write(s + '\n')

# %%
from IPython import get_ipython
get_ipython().system(f'''torchrun --nproc_per_node=4 qwen3_asr_sft.py \
  --model_path ./Qwen3-ASR-1.7B \
  --train_file data/feature/train_{version}.jsonl \
  --eval_file data/feature/valid_{version}.jsonl \
  --output_dir data/models/{version} \
  --batch_size 3 \
  --grad_acc 1 \
  --lr 2e-5 \
  --epochs 5 \
  --log_steps 10 \
  --save_strategy steps \
  --save_steps 28650 \
  --save_total_limit 5 \
  --num_workers 8 \
  --pin_memory 1 \
  --persistent_workers 1 \
  --prefetch_factor 2''')
# Out:
# W0308 11:31:09.538000 928679 site-packages/torch/distributed/run.py:803]
# W0308 11:31:09.538000 928679 site-packages/torch/distributed/run.py:803] *****************************************
# W0308 11:31:09.538000 928679 site-packages/torch/distributed/run.py:803] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0308 11:31:09.538000 928679 site-packages/torch/distributed/run.py:803] *****************************************
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:00<00:00,  9.83it/s]
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:00<00:00,  9.65it/s]
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:00<00:00,  9.68it/s]
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:00<00:00,  8.24it/s]
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# /data/xiaosa/Competitions/children_asr_word_track/qwen3_asr_sft.py:304: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `CastFloatInputsTrainer.__init__`. Use `processing_class` instead.
#   trainer = CastFloatInputsTrainer(
# /data/xiaosa/Competitions/children_asr_word_track/qwen3_asr_sft.py:304: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `CastFloatInputsTrainer.__init__`. Use `processing_class` instead.
#   trainer = CastFloatInputsTrainer(
# /data/xiaosa/Competitions/children_asr_word_track/qwen3_asr_sft.py:304: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `CastFloatInputsTrainer.__init__`. Use `processing_class` instead.
#   trainer = CastFloatInputsTrainer(
# /data/xiaosa/Competitions/children_asr_word_track/qwen3_asr_sft.py:304: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `CastFloatInputsTrainer.__init__`. Use `processing_class` instead.
#   trainer = CastFloatInputsTrainer(
# [2026-03-08 11:31:24,128] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2026-03-08 11:31:24,129] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2026-03-08 11:31:24,131] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2026-03-08 11:31:24,496] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 151645, 'pad_token_id': 151643}.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 151645, 'pad_token_id': 151643}.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 151645, 'pad_token_id': 151643}.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 151645, 'pad_token_id': 151643}.
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /home/ubuntu/anaconda3/lib/python3.10/site-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# {'loss': 40.6874, 'grad_norm': 2384.0, 'learning_rate': 6.282722513089006e-08, 'epoch': 0.0}
# {'loss': 41.0942, 'grad_norm': 1552.0, 'learning_rate': 1.3263525305410123e-07, 'epoch': 0.0}
# {'loss': 43.0485, 'grad_norm': 1344.0, 'learning_rate': 2.024432809773124e-07, 'epoch': 0.0}
# {'loss': 40.1937, 'grad_norm': 1104.0, 'learning_rate': 2.7225130890052355e-07, 'epoch': 0.0}
# {'loss': 39.2336, 'grad_norm': 1096.0, 'learning_rate': 3.4205933682373473e-07, 'epoch': 0.0}
# {'loss': 40.4599, 'grad_norm': 2096.0, 'learning_rate': 4.1186736474694596e-07, 'epoch': 0.0}
# {'loss': 39.5833, 'grad_norm': 1464.0, 'learning_rate': 4.816753926701571e-07, 'epoch': 0.0}
# {'loss': 40.1659, 'grad_norm': 1528.0, 'learning_rate': 5.514834205933683e-07, 'epoch': 0.0}
# {'loss': 37.7186, 'grad_norm': 1168.0, 'learning_rate': 6.212914485165794e-07, 'epoch': 0.0}
# {'loss': 38.72, 'grad_norm': 1064.0, 'learning_rate': 6.910994764397906e-07, 'epoch': 0.0}
# {'loss': 39.7565, 'grad_norm': 1168.0, 'learning_rate': 7.609075043630018e-07, 'epoch': 0.0}
# {'loss': 37.4504, 'grad_norm': 1856.0, 'learning_rate': 8.30715532286213e-07, 'epoch': 0.0}
# {'loss': 37.3542, 'grad_norm': 1840.0, 'learning_rate': 9.005235602094243e-07, 'epoch': 0.0}
# {'loss': 35.3634, 'grad_norm': 960.0, 'learning_rate': 9.703315881326353e-07, 'epoch': 0.0}
# {'loss': 38.5432, 'grad_norm': 900.0, 'learning_rate': 1.0401396160558465e-06, 'epoch': 0.01}
# {'loss': 34.0632, 'grad_norm': 1088.0, 'learning_rate': 1.1099476439790577e-06, 'epoch': 0.01}
# {'loss': 35.6583, 'grad_norm': 940.0, 'learning_rate': 1.179755671902269e-06, 'epoch': 0.01}
# {'loss': 30.6112, 'grad_norm': 808.0, 'learning_rate': 1.2495636998254802e-06, 'epoch': 0.01}
# {'loss': 31.6391, 'grad_norm': 764.0, 'learning_rate': 1.3193717277486912e-06, 'epoch': 0.01}
# {'loss': 29.4159, 'grad_norm': 864.0, 'learning_rate': 1.3891797556719024e-06, 'epoch': 0.01}
# {'loss': 28.3539, 'grad_norm': 652.0, 'learning_rate': 1.4589877835951135e-06, 'epoch': 0.01}
# {'loss': 23.8711, 'grad_norm': 1480.0, 'learning_rate': 1.5287958115183247e-06, 'epoch': 0.01}
# {'loss': 25.9493, 'grad_norm': 1392.0, 'learning_rate': 1.598603839441536e-06, 'epoch': 0.01}
# {'loss': 23.1437, 'grad_norm': 620.0, 'learning_rate': 1.668411867364747e-06, 'epoch': 0.01}
# {'loss': 21.4455, 'grad_norm': 780.0, 'learning_rate': 1.7382198952879584e-06, 'epoch': 0.01}
# {'loss': 16.9719, 'grad_norm': 264.0, 'learning_rate': 1.8080279232111694e-06, 'epoch': 0.01}
# {'loss': 18.5115, 'grad_norm': 820.0, 'learning_rate': 1.8778359511343804e-06, 'epoch': 0.01}
# {'loss': 17.9163, 'grad_norm': 952.0, 'learning_rate': 1.9476439790575916e-06, 'epoch': 0.01}
# {'loss': 17.9666, 'grad_norm': 772.0, 'learning_rate': 2.017452006980803e-06, 'epoch': 0.01}
# {'loss': 17.5361, 'grad_norm': 1416.0, 'learning_rate': 2.087260034904014e-06, 'epoch': 0.01}
# {'loss': 15.4454, 'grad_norm': 872.0, 'learning_rate': 2.157068062827225e-06, 'epoch': 0.01}
# {'loss': 17.082, 'grad_norm': 312.0, 'learning_rate': 2.2268760907504366e-06, 'epoch': 0.01}
# {'loss': 14.6029, 'grad_norm': 1000.0, 'learning_rate': 2.2966841186736476e-06, 'epoch': 0.01}
# {'loss': 16.8799, 'grad_norm': 908.0, 'learning_rate': 2.3664921465968586e-06, 'epoch': 0.01}
# {'loss': 16.0435, 'grad_norm': 836.0, 'learning_rate': 2.43630017452007e-06, 'epoch': 0.01}
# {'loss': 15.8695, 'grad_norm': 784.0, 'learning_rate': 2.5061082024432815e-06, 'epoch': 0.01}
# {'loss': 15.7977, 'grad_norm': 924.0, 'learning_rate': 2.5759162303664925e-06, 'epoch': 0.01}
# {'loss': 16.0712, 'grad_norm': 1012.0, 'learning_rate': 2.6457242582897035e-06, 'epoch': 0.01}
# {'loss': 15.2128, 'grad_norm': 272.0, 'learning_rate': 2.7155322862129145e-06, 'epoch': 0.01}
# {'loss': 13.1435, 'grad_norm': 378.0, 'learning_rate': 2.7853403141361256e-06, 'epoch': 0.01}
# {'loss': 14.1905, 'grad_norm': 308.0, 'learning_rate': 2.8551483420593374e-06, 'epoch': 0.01}
# {'loss': 12.9845, 'grad_norm': 324.0, 'learning_rate': 2.9249563699825484e-06, 'epoch': 0.01}
# {'loss': 12.6363, 'grad_norm': 450.0, 'learning_rate': 2.9947643979057595e-06, 'epoch': 0.02}
# {'loss': 11.909, 'grad_norm': 664.0, 'learning_rate': 3.0645724258289705e-06, 'epoch': 0.02}
# {'loss': 11.9874, 'grad_norm': 286.0, 'learning_rate': 3.1343804537521815e-06, 'epoch': 0.02}
# {'loss': 10.9841, 'grad_norm': 388.0, 'learning_rate': 3.2041884816753934e-06, 'epoch': 0.02}
# {'loss': 11.1451, 'grad_norm': 312.0, 'learning_rate': 3.2739965095986044e-06, 'epoch': 0.02}
# {'loss': 10.3799, 'grad_norm': 438.0, 'learning_rate': 3.3438045375218154e-06, 'epoch': 0.02}
# {'loss': 9.2709, 'grad_norm': 234.0, 'learning_rate': 3.4136125654450264e-06, 'epoch': 0.02}
# {'loss': 9.1849, 'grad_norm': 274.0, 'learning_rate': 3.4834205933682374e-06, 'epoch': 0.02}
# {'loss': 8.5454, 'grad_norm': 330.0, 'learning_rate': 3.553228621291449e-06, 'epoch': 0.02}
# {'loss': 8.19, 'grad_norm': 264.0, 'learning_rate': 3.6230366492146603e-06, 'epoch': 0.02}
# {'loss': 7.7012, 'grad_norm': 306.0, 'learning_rate': 3.6928446771378713e-06, 'epoch': 0.02}
# {'loss': 7.4441, 'grad_norm': 340.0, 'learning_rate': 3.7626527050610824e-06, 'epoch': 0.02}
# {'loss': 7.0649, 'grad_norm': 244.0, 'learning_rate': 3.832460732984293e-06, 'epoch': 0.02}
# {'loss': 6.9227, 'grad_norm': 374.0, 'learning_rate': 3.902268760907505e-06, 'epoch': 0.02}
# {'loss': 6.0184, 'grad_norm': 247.0, 'learning_rate': 3.972076788830716e-06, 'epoch': 0.02}
# {'loss': 5.5067, 'grad_norm': 211.0, 'learning_rate': 4.041884816753927e-06, 'epoch': 0.02}
# {'loss': 5.4029, 'grad_norm': 225.0, 'learning_rate': 4.111692844677138e-06, 'epoch': 0.02}
# {'loss': 5.2524, 'grad_norm': 133.0, 'learning_rate': 4.181500872600349e-06, 'epoch': 0.02}
# {'loss': 4.652, 'grad_norm': 221.0, 'learning_rate': 4.251308900523561e-06, 'epoch': 0.02}
# {'loss': 4.7001, 'grad_norm': 203.0, 'learning_rate': 4.321116928446772e-06, 'epoch': 0.02}
# {'loss': 4.3097, 'grad_norm': 324.0, 'learning_rate': 4.390924956369983e-06, 'epoch': 0.02}
# {'loss': 3.8759, 'grad_norm': 282.0, 'learning_rate': 4.460732984293194e-06, 'epoch': 0.02}
# {'loss': 3.9527, 'grad_norm': 256.0, 'learning_rate': 4.530541012216405e-06, 'epoch': 0.02}
# {'loss': 3.461, 'grad_norm': 444.0, 'learning_rate': 4.600349040139617e-06, 'epoch': 0.02}
# {'loss': 3.146, 'grad_norm': 274.0, 'learning_rate': 4.670157068062828e-06, 'epoch': 0.02}
# {'loss': 2.8189, 'grad_norm': 278.0, 'learning_rate': 4.739965095986039e-06, 'epoch': 0.02}
# {'loss': 2.767, 'grad_norm': 182.0, 'learning_rate': 4.80977312390925e-06, 'epoch': 0.02}
# {'loss': 2.3856, 'grad_norm': 189.0, 'learning_rate': 4.879581151832461e-06, 'epoch': 0.02}
# {'loss': 2.4148, 'grad_norm': 183.0, 'learning_rate': 4.949389179755672e-06, 'epoch': 0.02}
# {'loss': 2.1623, 'grad_norm': 165.0, 'learning_rate': 5.019197207678883e-06, 'epoch': 0.03}
# {'loss': 1.9758, 'grad_norm': 138.0, 'learning_rate': 5.089005235602095e-06, 'epoch': 0.03}
# {'loss': 2.0266, 'grad_norm': 152.0, 'learning_rate': 5.158813263525306e-06, 'epoch': 0.03}
# {'loss': 1.6053, 'grad_norm': 108.5, 'learning_rate': 5.228621291448517e-06, 'epoch': 0.03}
# {'loss': 1.6604, 'grad_norm': 266.0, 'learning_rate': 5.298429319371728e-06, 'epoch': 0.03}
# {'loss': 1.8425, 'grad_norm': 125.5, 'learning_rate': 5.368237347294939e-06, 'epoch': 0.03}
# {'loss': 1.6373, 'grad_norm': 176.0, 'learning_rate': 5.43804537521815e-06, 'epoch': 0.03}
# {'loss': 1.5092, 'grad_norm': 122.0, 'learning_rate': 5.507853403141362e-06, 'epoch': 0.03}
# {'loss': 1.4181, 'grad_norm': 133.0, 'learning_rate': 5.577661431064573e-06, 'epoch': 0.03}
# {'loss': 1.2736, 'grad_norm': 80.5, 'learning_rate': 5.647469458987784e-06, 'epoch': 0.03}
# {'loss': 1.4438, 'grad_norm': 74.0, 'learning_rate': 5.717277486910995e-06, 'epoch': 0.03}
# {'loss': 1.2655, 'grad_norm': 104.5, 'learning_rate': 5.787085514834206e-06, 'epoch': 0.03}
# {'loss': 1.1494, 'grad_norm': 90.5, 'learning_rate': 5.856893542757418e-06, 'epoch': 0.03}
# {'loss': 1.1723, 'grad_norm': 121.5, 'learning_rate': 5.926701570680628e-06, 'epoch': 0.03}
# {'loss': 1.1003, 'grad_norm': 84.5, 'learning_rate': 5.99650959860384e-06, 'epoch': 0.03}
# {'loss': 1.2184, 'grad_norm': 96.5, 'learning_rate': 6.066317626527051e-06, 'epoch': 0.03}
# {'loss': 0.9664, 'grad_norm': 90.0, 'learning_rate': 6.136125654450262e-06, 'epoch': 0.03}
# {'loss': 1.1531, 'grad_norm': 69.0, 'learning_rate': 6.205933682373474e-06, 'epoch': 0.03}
# {'loss': 0.9739, 'grad_norm': 110.5, 'learning_rate': 6.275741710296684e-06, 'epoch': 0.03}
# {'loss': 0.9866, 'grad_norm': 136.0, 'learning_rate': 6.345549738219896e-06, 'epoch': 0.03}
# {'loss': 0.921, 'grad_norm': 69.0, 'learning_rate': 6.415357766143107e-06, 'epoch': 0.03}
# {'loss': 0.9862, 'grad_norm': 90.0, 'learning_rate': 6.485165794066318e-06, 'epoch': 0.03}
# {'loss': 1.0239, 'grad_norm': 120.5, 'learning_rate': 6.55497382198953e-06, 'epoch': 0.03}
# {'loss': 0.9525, 'grad_norm': 50.5, 'learning_rate': 6.62478184991274e-06, 'epoch': 0.03}
# {'loss': 0.882, 'grad_norm': 60.5, 'learning_rate': 6.694589877835952e-06, 'epoch': 0.03}
# {'loss': 0.8972, 'grad_norm': 86.0, 'learning_rate': 6.764397905759162e-06, 'epoch': 0.03}
# {'loss': 0.8214, 'grad_norm': 67.0, 'learning_rate': 6.834205933682374e-06, 'epoch': 0.03}
# {'loss': 0.8403, 'grad_norm': 43.75, 'learning_rate': 6.904013961605586e-06, 'epoch': 0.03}
# {'loss': 0.774, 'grad_norm': 51.5, 'learning_rate': 6.973821989528796e-06, 'epoch': 0.03}
# {'loss': 0.8138, 'grad_norm': 41.0, 'learning_rate': 7.043630017452008e-06, 'epoch': 0.04}
# {'loss': 0.8506, 'grad_norm': 39.0, 'learning_rate': 7.113438045375218e-06, 'epoch': 0.04}
# {'loss': 0.6398, 'grad_norm': 58.75, 'learning_rate': 7.18324607329843e-06, 'epoch': 0.04}
# {'loss': 0.9443, 'grad_norm': 57.75, 'learning_rate': 7.253054101221642e-06, 'epoch': 0.04}
# {'loss': 0.8377, 'grad_norm': 102.5, 'learning_rate': 7.322862129144852e-06, 'epoch': 0.04}
# {'loss': 0.6971, 'grad_norm': 79.5, 'learning_rate': 7.392670157068064e-06, 'epoch': 0.04}
# {'loss': 0.7349, 'grad_norm': 41.5, 'learning_rate': 7.462478184991274e-06, 'epoch': 0.04}
# {'loss': 0.6282, 'grad_norm': 45.5, 'learning_rate': 7.532286212914486e-06, 'epoch': 0.04}
# {'loss': 0.5311, 'grad_norm': 32.0, 'learning_rate': 7.602094240837698e-06, 'epoch': 0.04}
# {'loss': 0.5546, 'grad_norm': 35.5, 'learning_rate': 7.671902268760909e-06, 'epoch': 0.04}
# {'loss': 0.6493, 'grad_norm': 47.5, 'learning_rate': 7.74171029668412e-06, 'epoch': 0.04}
# {'loss': 0.7791, 'grad_norm': 44.75, 'learning_rate': 7.81151832460733e-06, 'epoch': 0.04}
# {'loss': 0.6875, 'grad_norm': 172.0, 'learning_rate': 7.881326352530542e-06, 'epoch': 0.04}
# {'loss': 0.5227, 'grad_norm': 33.5, 'learning_rate': 7.951134380453753e-06, 'epoch': 0.04}
# {'loss': 0.4918, 'grad_norm': 46.5, 'learning_rate': 8.020942408376964e-06, 'epoch': 0.04}
# {'loss': 0.6323, 'grad_norm': 42.5, 'learning_rate': 8.090750436300175e-06, 'epoch': 0.04}
# {'loss': 0.5641, 'grad_norm': 34.25, 'learning_rate': 8.160558464223386e-06, 'epoch': 0.04}
# {'loss': 0.5763, 'grad_norm': 45.75, 'learning_rate': 8.230366492146597e-06, 'epoch': 0.04}
# {'loss': 0.6442, 'grad_norm': 40.0, 'learning_rate': 8.30017452006981e-06, 'epoch': 0.04}
# {'loss': 0.8378, 'grad_norm': 21.125, 'learning_rate': 8.369982547993019e-06, 'epoch': 0.04}
# {'loss': 0.7364, 'grad_norm': 51.75, 'learning_rate': 8.439790575916232e-06, 'epoch': 0.04}
# {'loss': 0.6321, 'grad_norm': 24.0, 'learning_rate': 8.509598603839443e-06, 'epoch': 0.04}
# {'loss': 0.6294, 'grad_norm': 33.25, 'learning_rate': 8.579406631762654e-06, 'epoch': 0.04}
# {'loss': 0.5933, 'grad_norm': 51.25, 'learning_rate': 8.649214659685865e-06, 'epoch': 0.04}
# {'loss': 0.4849, 'grad_norm': 35.25, 'learning_rate': 8.719022687609076e-06, 'epoch': 0.04}
# {'loss': 0.5701, 'grad_norm': 50.75, 'learning_rate': 8.788830715532287e-06, 'epoch': 0.04}
# {'loss': 0.5151, 'grad_norm': 52.0, 'learning_rate': 8.858638743455498e-06, 'epoch': 0.04}
# {'loss': 0.6543, 'grad_norm': 28.625, 'learning_rate': 8.928446771378709e-06, 'epoch': 0.04}
# {'loss': 0.6995, 'grad_norm': 55.0, 'learning_rate': 8.998254799301921e-06, 'epoch': 0.05}
# {'loss': 0.5605, 'grad_norm': 50.5, 'learning_rate': 9.06806282722513e-06, 'epoch': 0.05}
# {'loss': 0.5314, 'grad_norm': 27.875, 'learning_rate': 9.137870855148343e-06, 'epoch': 0.05}
# {'loss': 0.4824, 'grad_norm': 17.25, 'learning_rate': 9.207678883071553e-06, 'epoch': 0.05}
# {'loss': 0.5154, 'grad_norm': 47.5, 'learning_rate': 9.277486910994766e-06, 'epoch': 0.05}
# {'loss': 0.7254, 'grad_norm': 28.875, 'learning_rate': 9.347294938917977e-06, 'epoch': 0.05}
# {'loss': 0.5195, 'grad_norm': 28.25, 'learning_rate': 9.417102966841188e-06, 'epoch': 0.05}
# {'loss': 0.5211, 'grad_norm': 71.5, 'learning_rate': 9.486910994764399e-06, 'epoch': 0.05}
# {'loss': 0.5541, 'grad_norm': 35.25, 'learning_rate': 9.55671902268761e-06, 'epoch': 0.05}
# {'loss': 0.7195, 'grad_norm': 36.25, 'learning_rate': 9.62652705061082e-06, 'epoch': 0.05}
# {'loss': 0.3899, 'grad_norm': 23.0, 'learning_rate': 9.696335078534033e-06, 'epoch': 0.05}
# {'loss': 0.4608, 'grad_norm': 50.25, 'learning_rate': 9.766143106457243e-06, 'epoch': 0.05}
# {'loss': 0.4845, 'grad_norm': 31.125, 'learning_rate': 9.835951134380455e-06, 'epoch': 0.05}
# {'loss': 0.4663, 'grad_norm': 20.25, 'learning_rate': 9.905759162303665e-06, 'epoch': 0.05}
# {'loss': 0.5793, 'grad_norm': 32.75, 'learning_rate': 9.975567190226877e-06, 'epoch': 0.05}
# {'loss': 0.4608, 'grad_norm': 35.5, 'learning_rate': 1.0045375218150088e-05, 'epoch': 0.05}
# {'loss': 0.524, 'grad_norm': 57.25, 'learning_rate': 1.01151832460733e-05, 'epoch': 0.05}
# {'loss': 0.5038, 'grad_norm': 21.0, 'learning_rate': 1.0184991273996509e-05, 'epoch': 0.05}
# {'loss': 0.525, 'grad_norm': 29.75, 'learning_rate': 1.0254799301919721e-05, 'epoch': 0.05}
# {'loss': 0.3871, 'grad_norm': 20.875, 'learning_rate': 1.0324607329842932e-05, 'epoch': 0.05}
# {'loss': 0.4147, 'grad_norm': 35.0, 'learning_rate': 1.0394415357766143e-05, 'epoch': 0.05}
# {'loss': 0.3378, 'grad_norm': 22.75, 'learning_rate': 1.0464223385689356e-05, 'epoch': 0.05}
# {'loss': 0.4889, 'grad_norm': 29.875, 'learning_rate': 1.0534031413612567e-05, 'epoch': 0.05}
# {'loss': 0.4706, 'grad_norm': 29.875, 'learning_rate': 1.0603839441535777e-05, 'epoch': 0.05}
# {'loss': 0.5338, 'grad_norm': 27.75, 'learning_rate': 1.0673647469458988e-05, 'epoch': 0.05}
# {'loss': 0.5539, 'grad_norm': 25.75, 'learning_rate': 1.07434554973822e-05, 'epoch': 0.05}
# {'loss': 0.4904, 'grad_norm': 30.75, 'learning_rate': 1.0813263525305411e-05, 'epoch': 0.05}
# {'loss': 0.4047, 'grad_norm': 31.75, 'learning_rate': 1.088307155322862e-05, 'epoch': 0.05}
# {'loss': 0.4979, 'grad_norm': 26.375, 'learning_rate': 1.0952879581151833e-05, 'epoch': 0.05}
# {'loss': 0.5364, 'grad_norm': 24.25, 'learning_rate': 1.1022687609075044e-05, 'epoch': 0.06}
# {'loss': 0.3825, 'grad_norm': 43.25, 'learning_rate': 1.1092495636998255e-05, 'epoch': 0.06}
# {'loss': 0.6182, 'grad_norm': 80.0, 'learning_rate': 1.1162303664921468e-05, 'epoch': 0.06}
# {'loss': 0.4352, 'grad_norm': 30.25, 'learning_rate': 1.1232111692844679e-05, 'epoch': 0.06}
# {'loss': 0.5304, 'grad_norm': 26.0, 'learning_rate': 1.1301919720767888e-05, 'epoch': 0.06}
# {'loss': 0.5156, 'grad_norm': 20.5, 'learning_rate': 1.13717277486911e-05, 'epoch': 0.06}
# {'loss': 0.4112, 'grad_norm': 42.0, 'learning_rate': 1.1441535776614312e-05, 'epoch': 0.06}
# {'loss': 0.524, 'grad_norm': 11.9375, 'learning_rate': 1.1511343804537523e-05, 'epoch': 0.06}
# {'loss': 0.4355, 'grad_norm': 30.875, 'learning_rate': 1.1581151832460733e-05, 'epoch': 0.06}
# {'loss': 0.4637, 'grad_norm': 31.25, 'learning_rate': 1.1650959860383945e-05, 'epoch': 0.06}
# {'loss': 0.5849, 'grad_norm': 45.75, 'learning_rate': 1.1720767888307156e-05, 'epoch': 0.06}
# {'loss': 0.3815, 'grad_norm': 12.6875, 'learning_rate': 1.1790575916230367e-05, 'epoch': 0.06}
# {'loss': 0.5405, 'grad_norm': 40.75, 'learning_rate': 1.186038394415358e-05, 'epoch': 0.06}
# {'loss': 0.5432, 'grad_norm': 35.75, 'learning_rate': 1.193019197207679e-05, 'epoch': 0.06}
# {'loss': 0.5941, 'grad_norm': 25.875, 'learning_rate': 1.2e-05, 'epoch': 0.06}
# {'loss': 0.4349, 'grad_norm': 17.375, 'learning_rate': 1.2069808027923213e-05, 'epoch': 0.06}
# {'loss': 0.5423, 'grad_norm': 38.75, 'learning_rate': 1.2139616055846424e-05, 'epoch': 0.06}
# {'loss': 0.4078, 'grad_norm': 31.375, 'learning_rate': 1.2209424083769635e-05, 'epoch': 0.06}
# {'loss': 0.5691, 'grad_norm': 59.0, 'learning_rate': 1.2279232111692844e-05, 'epoch': 0.06}
# {'loss': 0.512, 'grad_norm': 38.75, 'learning_rate': 1.2349040139616057e-05, 'epoch': 0.06}
# {'loss': 0.4461, 'grad_norm': 30.125, 'learning_rate': 1.2418848167539268e-05, 'epoch': 0.06}
# {'loss': 0.6053, 'grad_norm': 46.5, 'learning_rate': 1.2488656195462479e-05, 'epoch': 0.06}
# {'loss': 0.5466, 'grad_norm': 26.25, 'learning_rate': 1.2558464223385692e-05, 'epoch': 0.06}
# {'loss': 0.4428, 'grad_norm': 22.75, 'learning_rate': 1.2628272251308901e-05, 'epoch': 0.06}
# {'loss': 0.4803, 'grad_norm': 147.0, 'learning_rate': 1.2698080279232112e-05, 'epoch': 0.06}
# {'loss': 0.3129, 'grad_norm': 35.0, 'learning_rate': 1.2767888307155325e-05, 'epoch': 0.06}
# {'loss': 0.4655, 'grad_norm': 24.25, 'learning_rate': 1.2837696335078536e-05, 'epoch': 0.06}
# {'loss': 0.4889, 'grad_norm': 40.0, 'learning_rate': 1.2907504363001745e-05, 'epoch': 0.06}
# {'loss': 0.421, 'grad_norm': 34.5, 'learning_rate': 1.2977312390924956e-05, 'epoch': 0.06}
# {'loss': 0.3291, 'grad_norm': 16.5, 'learning_rate': 1.3047120418848169e-05, 'epoch': 0.07}
# {'loss': 0.4369, 'grad_norm': 28.5, 'learning_rate': 1.311692844677138e-05, 'epoch': 0.07}
# {'loss': 0.5495, 'grad_norm': 1008.0, 'learning_rate': 1.3186736474694591e-05, 'epoch': 0.07}
# {'loss': 1.0715, 'grad_norm': 1256.0, 'learning_rate': 1.3256544502617804e-05, 'epoch': 0.07}
# {'loss': 1.0712, 'grad_norm': 424.0, 'learning_rate': 1.3326352530541013e-05, 'epoch': 0.07}
# {'loss': 1.016, 'grad_norm': 223.0, 'learning_rate': 1.3396160558464224e-05, 'epoch': 0.07}
# {'loss': 0.7346, 'grad_norm': 23.125, 'learning_rate': 1.3465968586387437e-05, 'epoch': 0.07}
# {'loss': 0.4748, 'grad_norm': 43.5, 'learning_rate': 1.3535776614310648e-05, 'epoch': 0.07}
# {'loss': 0.6693, 'grad_norm': 21.5, 'learning_rate': 1.3605584642233857e-05, 'epoch': 0.07}
# {'loss': 0.5297, 'grad_norm': 22.125, 'learning_rate': 1.3675392670157068e-05, 'epoch': 0.07}
# {'loss': 0.4262, 'grad_norm': 13.6875, 'learning_rate': 1.374520069808028e-05, 'epoch': 0.07}
# {'loss': 0.5796, 'grad_norm': 55.75, 'learning_rate': 1.3815008726003492e-05, 'epoch': 0.07}
# {'loss': 0.475, 'grad_norm': 20.75, 'learning_rate': 1.3884816753926701e-05, 'epoch': 0.07}
# {'loss': 0.5073, 'grad_norm': 30.625, 'learning_rate': 1.3954624781849916e-05, 'epoch': 0.07}
# {'loss': 0.4706, 'grad_norm': 36.5, 'learning_rate': 1.4024432809773125e-05, 'epoch': 0.07}
# {'loss': 0.433, 'grad_norm': 37.0, 'learning_rate': 1.4094240837696336e-05, 'epoch': 0.07}
# {'loss': 0.5039, 'grad_norm': 39.0, 'learning_rate': 1.4164048865619549e-05, 'epoch': 0.07}
# {'loss': 0.3777, 'grad_norm': 26.75, 'learning_rate': 1.423385689354276e-05, 'epoch': 0.07}
# {'loss': 0.5928, 'grad_norm': 34.5, 'learning_rate': 1.4303664921465969e-05, 'epoch': 0.07}
# {'loss': 0.4819, 'grad_norm': 69.0, 'learning_rate': 1.437347294938918e-05, 'epoch': 0.07}
# {'loss': 0.3416, 'grad_norm': 14.5, 'learning_rate': 1.4443280977312393e-05, 'epoch': 0.07}
# {'loss': 0.6183, 'grad_norm': 31.875, 'learning_rate': 1.4513089005235604e-05, 'epoch': 0.07}
# {'loss': 0.4854, 'grad_norm': 24.5, 'learning_rate': 1.4582897033158813e-05, 'epoch': 0.07}
# {'loss': 0.4669, 'grad_norm': 25.75, 'learning_rate': 1.4652705061082026e-05, 'epoch': 0.07}
# {'loss': 0.6131, 'grad_norm': 49.25, 'learning_rate': 1.4722513089005237e-05, 'epoch': 0.07}
# {'loss': 0.4974, 'grad_norm': 17.875, 'learning_rate': 1.4792321116928448e-05, 'epoch': 0.07}
# {'loss': 0.4506, 'grad_norm': 34.75, 'learning_rate': 1.486212914485166e-05, 'epoch': 0.07}
# {'loss': 0.5015, 'grad_norm': 17.0, 'learning_rate': 1.4931937172774872e-05, 'epoch': 0.07}
# {'loss': 0.5342, 'grad_norm': 16.375, 'learning_rate': 1.5001745200698081e-05, 'epoch': 0.08}
# {'loss': 0.4332, 'grad_norm': 19.375, 'learning_rate': 1.5071553228621292e-05, 'epoch': 0.08}
# {'loss': 0.3624, 'grad_norm': 10.375, 'learning_rate': 1.5141361256544505e-05, 'epoch': 0.08}
# {'loss': 0.4603, 'grad_norm': 25.375, 'learning_rate': 1.5211169284467716e-05, 'epoch': 0.08}
# {'loss': 0.5632, 'grad_norm': 40.0, 'learning_rate': 1.5280977312390927e-05, 'epoch': 0.08}
# {'loss': 0.4383, 'grad_norm': 28.25, 'learning_rate': 1.535078534031414e-05, 'epoch': 0.08}
# {'loss': 0.4407, 'grad_norm': 15.1875, 'learning_rate': 1.542059336823735e-05, 'epoch': 0.08}
# {'loss': 0.5292, 'grad_norm': 29.5, 'learning_rate': 1.5490401396160558e-05, 'epoch': 0.08}
# {'loss': 0.5385, 'grad_norm': 30.5, 'learning_rate': 1.556020942408377e-05, 'epoch': 0.08}
# {'loss': 0.4501, 'grad_norm': 25.0, 'learning_rate': 1.5630017452006983e-05, 'epoch': 0.08}
# {'loss': 0.4582, 'grad_norm': 28.875, 'learning_rate': 1.5699825479930193e-05, 'epoch': 0.08}
# {'loss': 0.4879, 'grad_norm': 12.5, 'learning_rate': 1.5769633507853402e-05, 'epoch': 0.08}
# {'loss': 0.449, 'grad_norm': 28.25, 'learning_rate': 1.5839441535776615e-05, 'epoch': 0.08}
# {'loss': 0.4251, 'grad_norm': 55.25, 'learning_rate': 1.5909249563699827e-05, 'epoch': 0.08}
# {'loss': 0.4344, 'grad_norm': 21.125, 'learning_rate': 1.5979057591623037e-05, 'epoch': 0.08}
# {'loss': 0.3989, 'grad_norm': 18.0, 'learning_rate': 1.604886561954625e-05, 'epoch': 0.08}
# {'loss': 0.443, 'grad_norm': 26.875, 'learning_rate': 1.611867364746946e-05, 'epoch': 0.08}
# {'loss': 0.4086, 'grad_norm': 14.1875, 'learning_rate': 1.618848167539267e-05, 'epoch': 0.08}
# {'loss': 0.357, 'grad_norm': 38.0, 'learning_rate': 1.6258289703315884e-05, 'epoch': 0.08}
# {'loss': 0.4347, 'grad_norm': 23.5, 'learning_rate': 1.6328097731239094e-05, 'epoch': 0.08}
# {'loss': 0.4334, 'grad_norm': 39.25, 'learning_rate': 1.6397905759162306e-05, 'epoch': 0.08}
# {'loss': 0.5359, 'grad_norm': 19.5, 'learning_rate': 1.6467713787085516e-05, 'epoch': 0.08}
# {'loss': 0.4421, 'grad_norm': 14.5, 'learning_rate': 1.653752181500873e-05, 'epoch': 0.08}
# {'loss': 0.371, 'grad_norm': 8.5625, 'learning_rate': 1.6607329842931938e-05, 'epoch': 0.08}
# {'loss': 0.3998, 'grad_norm': 25.125, 'learning_rate': 1.667713787085515e-05, 'epoch': 0.08}
# {'loss': 0.4189, 'grad_norm': 17.0, 'learning_rate': 1.6746945898778363e-05, 'epoch': 0.08}
# {'loss': 0.3416, 'grad_norm': 23.75, 'learning_rate': 1.6816753926701572e-05, 'epoch': 0.08}
# {'loss': 0.3918, 'grad_norm': 30.625, 'learning_rate': 1.6886561954624782e-05, 'epoch': 0.08}
# {'loss': 0.5377, 'grad_norm': 18.25, 'learning_rate': 1.6956369982547994e-05, 'epoch': 0.08}
# {'loss': 0.3473, 'grad_norm': 12.0, 'learning_rate': 1.7026178010471207e-05, 'epoch': 0.09}
# {'loss': 0.3835, 'grad_norm': 20.375, 'learning_rate': 1.7095986038394416e-05, 'epoch': 0.09}
# {'loss': 0.4144, 'grad_norm': 21.75, 'learning_rate': 1.7165794066317626e-05, 'epoch': 0.09}
# {'loss': 0.4587, 'grad_norm': 20.25, 'learning_rate': 1.723560209424084e-05, 'epoch': 0.09}
# {'loss': 0.4037, 'grad_norm': 18.0, 'learning_rate': 1.730541012216405e-05, 'epoch': 0.09}
# {'loss': 0.6383, 'grad_norm': 20.375, 'learning_rate': 1.737521815008726e-05, 'epoch': 0.09}
# {'loss': 0.4237, 'grad_norm': 46.5, 'learning_rate': 1.7445026178010473e-05, 'epoch': 0.09}
# {'loss': 0.3663, 'grad_norm': 7.34375, 'learning_rate': 1.7514834205933683e-05, 'epoch': 0.09}
# {'loss': 0.3299, 'grad_norm': 20.75, 'learning_rate': 1.7584642233856895e-05, 'epoch': 0.09}
# {'loss': 0.4048, 'grad_norm': 30.0, 'learning_rate': 1.7654450261780108e-05, 'epoch': 0.09}
# {'loss': 0.3897, 'grad_norm': 36.5, 'learning_rate': 1.7724258289703317e-05, 'epoch': 0.09}
# {'loss': 0.3539, 'grad_norm': 18.25, 'learning_rate': 1.7794066317626527e-05, 'epoch': 0.09}
# {'loss': 0.3903, 'grad_norm': 35.75, 'learning_rate': 1.786387434554974e-05, 'epoch': 0.09}
# {'loss': 0.4475, 'grad_norm': 29.625, 'learning_rate': 1.7933682373472952e-05, 'epoch': 0.09}
# {'loss': 0.3296, 'grad_norm': 31.125, 'learning_rate': 1.800349040139616e-05, 'epoch': 0.09}
# {'loss': 0.5216, 'grad_norm': 17.5, 'learning_rate': 1.8073298429319374e-05, 'epoch': 0.09}
# {'loss': 0.4336, 'grad_norm': 10.375, 'learning_rate': 1.8143106457242587e-05, 'epoch': 0.09}
# {'loss': 0.6869, 'grad_norm': 20.625, 'learning_rate': 1.8212914485165796e-05, 'epoch': 0.09}
# {'loss': 0.6388, 'grad_norm': 65.5, 'learning_rate': 1.8282722513089006e-05, 'epoch': 0.09}
# {'loss': 0.4298, 'grad_norm': 19.5, 'learning_rate': 1.8352530541012218e-05, 'epoch': 0.09}
# {'loss': 0.2944, 'grad_norm': 16.5, 'learning_rate': 1.842233856893543e-05, 'epoch': 0.09}
# {'loss': 0.4747, 'grad_norm': 16.875, 'learning_rate': 1.849214659685864e-05, 'epoch': 0.09}
# {'loss': 0.5278, 'grad_norm': 31.125, 'learning_rate': 1.856195462478185e-05, 'epoch': 0.09}
# {'loss': 0.446, 'grad_norm': 28.0, 'learning_rate': 1.8631762652705062e-05, 'epoch': 0.09}
# {'loss': 0.4538, 'grad_norm': 27.625, 'learning_rate': 1.8701570680628275e-05, 'epoch': 0.09}
# {'loss': 0.4598, 'grad_norm': 26.875, 'learning_rate': 1.8771378708551484e-05, 'epoch': 0.09}
# {'loss': 0.3608, 'grad_norm': 22.0, 'learning_rate': 1.8841186736474697e-05, 'epoch': 0.09}
# {'loss': 0.3331, 'grad_norm': 35.0, 'learning_rate': 1.8910994764397906e-05, 'epoch': 0.09}
# {'loss': 0.4971, 'grad_norm': 25.25, 'learning_rate': 1.898080279232112e-05, 'epoch': 0.09}
# {'loss': 0.3349, 'grad_norm': 26.0, 'learning_rate': 1.9050610820244332e-05, 'epoch': 0.1}
# {'loss': 0.428, 'grad_norm': 23.0, 'learning_rate': 1.912041884816754e-05, 'epoch': 0.1}
# {'loss': 0.5512, 'grad_norm': 15.25, 'learning_rate': 1.919022687609075e-05, 'epoch': 0.1}
# {'loss': 0.6201, 'grad_norm': 29.0, 'learning_rate': 1.9260034904013963e-05, 'epoch': 0.1}
# {'loss': 0.4996, 'grad_norm': 12.1875, 'learning_rate': 1.9329842931937176e-05, 'epoch': 0.1}
# {'loss': 0.4053, 'grad_norm': 23.875, 'learning_rate': 1.9399650959860385e-05, 'epoch': 0.1}
# {'loss': 0.3264, 'grad_norm': 25.0, 'learning_rate': 1.9469458987783595e-05, 'epoch': 0.1}
# {'loss': 0.3942, 'grad_norm': 37.75, 'learning_rate': 1.9539267015706807e-05, 'epoch': 0.1}
# {'loss': 0.4559, 'grad_norm': 22.625, 'learning_rate': 1.960907504363002e-05, 'epoch': 0.1}
# {'loss': 0.3893, 'grad_norm': 24.0, 'learning_rate': 1.967888307155323e-05, 'epoch': 0.1}
# {'loss': 0.4692, 'grad_norm': 16.125, 'learning_rate': 1.9748691099476442e-05, 'epoch': 0.1}
# {'loss': 0.3704, 'grad_norm': 30.625, 'learning_rate': 1.981849912739965e-05, 'epoch': 0.1}
# {'loss': 0.4521, 'grad_norm': 20.5, 'learning_rate': 1.9888307155322864e-05, 'epoch': 0.1}
# {'loss': 0.4454, 'grad_norm': 13.5625, 'learning_rate': 1.9958115183246073e-05, 'epoch': 0.1}
# {'loss': 0.4084, 'grad_norm': 17.25, 'learning_rate': 1.9999430138547565e-05, 'epoch': 0.1}
# {'loss': 0.4587, 'grad_norm': 6.78125, 'learning_rate': 1.999800548491648e-05, 'epoch': 0.1}
# {'loss': 0.3324, 'grad_norm': 19.75, 'learning_rate': 1.9996580831285395e-05, 'epoch': 0.1}
# {'loss': 0.4722, 'grad_norm': 28.875, 'learning_rate': 1.999515617765431e-05, 'epoch': 0.1}
# {'loss': 0.3397, 'grad_norm': 34.0, 'learning_rate': 1.9993731524023224e-05, 'epoch': 0.1}
# {'loss': 0.3869, 'grad_norm': 15.875, 'learning_rate': 1.999230687039214e-05, 'epoch': 0.1}
# {'loss': 0.4638, 'grad_norm': 29.75, 'learning_rate': 1.9990882216761053e-05, 'epoch': 0.1}
# {'loss': 0.3302, 'grad_norm': 16.25, 'learning_rate': 1.9989457563129965e-05, 'epoch': 0.1}
# {'loss': 0.4096, 'grad_norm': 30.375, 'learning_rate': 1.998803290949888e-05, 'epoch': 0.1}
# {'loss': 0.4171, 'grad_norm': 38.75, 'learning_rate': 1.9986608255867794e-05, 'epoch': 0.1}
# {'loss': 0.4511, 'grad_norm': 27.875, 'learning_rate': 1.998518360223671e-05, 'epoch': 0.1}
# {'loss': 0.5532, 'grad_norm': 32.5, 'learning_rate': 1.9983758948605623e-05, 'epoch': 0.1}
# {'loss': 0.3665, 'grad_norm': 14.8125, 'learning_rate': 1.9982334294974538e-05, 'epoch': 0.1}
# {'loss': 0.5899, 'grad_norm': 24.0, 'learning_rate': 1.998090964134345e-05, 'epoch': 0.1}
# {'loss': 0.3937, 'grad_norm': 22.875, 'learning_rate': 1.9979484987712364e-05, 'epoch': 0.11}
# {'loss': 0.3709, 'grad_norm': 8.5, 'learning_rate': 1.997806033408128e-05, 'epoch': 0.11}
# {'loss': 0.3046, 'grad_norm': 39.5, 'learning_rate': 1.9976635680450193e-05, 'epoch': 0.11}
# {'loss': 0.4026, 'grad_norm': 29.625, 'learning_rate': 1.9975211026819104e-05, 'epoch': 0.11}
# {'loss': 0.5248, 'grad_norm': 17.625, 'learning_rate': 1.997378637318802e-05, 'epoch': 0.11}
# {'loss': 0.377, 'grad_norm': 20.875, 'learning_rate': 1.9972361719556934e-05, 'epoch': 0.11}
# {'loss': 0.4718, 'grad_norm': 31.5, 'learning_rate': 1.9970937065925848e-05, 'epoch': 0.11}
# {'loss': 0.3266, 'grad_norm': 19.125, 'learning_rate': 1.9969512412294763e-05, 'epoch': 0.11}
# {'loss': 0.4351, 'grad_norm': 29.875, 'learning_rate': 1.9968087758663678e-05, 'epoch': 0.11}
# {'loss': 0.5735, 'grad_norm': 24.625, 'learning_rate': 1.9966663105032592e-05, 'epoch': 0.11}
# {'loss': 0.4239, 'grad_norm': 10.8125, 'learning_rate': 1.9965238451401507e-05, 'epoch': 0.11}
# {'loss': 0.3457, 'grad_norm': 20.875, 'learning_rate': 1.9963813797770418e-05, 'epoch': 0.11}
# {'loss': 0.4718, 'grad_norm': 13.9375, 'learning_rate': 1.9962389144139333e-05, 'epoch': 0.11}
# {'loss': 0.4302, 'grad_norm': 17.25, 'learning_rate': 1.9960964490508247e-05, 'epoch': 0.11}
# {'loss': 0.5057, 'grad_norm': 42.0, 'learning_rate': 1.995953983687716e-05, 'epoch': 0.11}
# {'loss': 0.4848, 'grad_norm': 38.5, 'learning_rate': 1.9958115183246073e-05, 'epoch': 0.11}
# {'loss': 0.4465, 'grad_norm': 14.125, 'learning_rate': 1.9956690529614988e-05, 'epoch': 0.11}
# {'loss': 0.4002, 'grad_norm': 15.5, 'learning_rate': 1.9955265875983903e-05, 'epoch': 0.11}
# {'loss': 0.4543, 'grad_norm': 27.0, 'learning_rate': 1.9953841222352817e-05, 'epoch': 0.11}
# {'loss': 0.4261, 'grad_norm': 33.5, 'learning_rate': 1.9952416568721732e-05, 'epoch': 0.11}
# {'loss': 0.3598, 'grad_norm': 13.5, 'learning_rate': 1.9950991915090647e-05, 'epoch': 0.11}
# {'loss': 0.5915, 'grad_norm': 36.75, 'learning_rate': 1.9949567261459558e-05, 'epoch': 0.11}
# {'loss': 0.4425, 'grad_norm': 31.0, 'learning_rate': 1.9948142607828472e-05, 'epoch': 0.11}
# {'loss': 0.4775, 'grad_norm': 34.25, 'learning_rate': 1.9946717954197387e-05, 'epoch': 0.11}
# {'loss': 0.4579, 'grad_norm': 18.375, 'learning_rate': 1.9945293300566302e-05, 'epoch': 0.11}
#   2%|▊                                 | 3257/143250 [49:00<34:50:20,  1.12it/s]
